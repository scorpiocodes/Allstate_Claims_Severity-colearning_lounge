# %% [markdown]
# <a href="https://colab.research.google.com/github/scorpiocodes/Allstate_Claims_Severity-colearning_lounge/blob/master/allstate_claim_severity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-6d764e3f-fd6f-4e0c-b789-7e6bb5c1f144" name="files[]" multiple disabled />
#      <output id="result-6d764e3f-fd6f-4e0c-b789-7e6bb5c1f144">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"unpredictable11","key":"2cf615ee80248fa3faaf8fcbef72a113"}'}

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c allstate-claims-severity

# %%
# !unzip \*.zip

# %%
import pandas as pd
train_data = pd.read_csv('train.csv')
train_data.head(10)
# Out:
#    id cat1 cat2 cat3 cat4  ...    cont11    cont12    cont13    cont14      loss
# 0   1    A    B    A    B  ...  0.569745  0.594646  0.822493  0.714843   2213.18
# 1   2    A    B    A    A  ...  0.338312  0.366307  0.611431  0.304496   1283.60
# 2   5    A    B    A    A  ...  0.381398  0.373424  0.195709  0.774425   3005.09
# 3  10    B    B    A    B  ...  0.327915  0.321570  0.605077  0.602642    939.85
# 4  11    A    B    A    B  ...  0.204687  0.202213  0.246011  0.432606   2763.85
# 5  13    A    B    A    A  ...  0.366788  0.359249  0.345247  0.726792   5142.87
# 6  14    A    A    A    A  ...  0.334828  0.352251  0.342239  0.382931   1132.22
# 7  20    A    B    A    B  ...  0.644013  0.785706  0.859764  0.242416   3585.75
# 8  23    A    B    B    B  ...  0.682315  0.669033  0.756454  0.361191  10280.20
# 9  24    A    B    A    A  ...  0.863052  0.879347  0.822493  0.294523   6184.59
#
# [10 rows x 132 columns]
